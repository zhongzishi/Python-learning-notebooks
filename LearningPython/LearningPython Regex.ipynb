# %%
import re
# compile pattern
pattern = re.compile(r'^\d{3}\-\d{3,8}$')
result = pattern.search('010-12345') 
# return an object
print(result)
# Out:
# <_sre.SRE_Match object; span=(0, 9), match='010-12345'>

# %%
#example
pattern = re.compile(r'^\d{3}\-\d{3,8}$')
if pattern.search('010-12345'):
    print("OK")
else:
    print("Not found")
# Out:
# OK

# %%
"""
pattern = re.compile(pattern)
pattern.match(string)
are same as
re.match(pattern,string)
"""
if re.match(r'^\d{3}\-\d{3,8}$','010-12345'):
    print("OK")
else:
    print("Not found")
# Out:
# OK

# %%
print("OK") if re.match(r'^\d{3}\-\d{3,8}$','010-12345') else print("Not found")
# Out:
# OK

# %%
print(re.findall('car','carry the barcardi to the car'))
# Out:
# ['car', 'car', 'car']

# %%
s = "This and that"
re.findall('(th\w+)',s,re.I)
# Out:
# ['This', 'that']

# %%
for i in re.finditer(r'(th\w+)',s,re.I):
    print(i)
# Out:
# <_sre.SRE_Match object; span=(0, 4), match='This'>
# <_sre.SRE_Match object; span=(9, 13), match='that'>

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-06d12db7c586> in <module>()
#       1 it = re.finditer(r'(th\w+)',s,re.I)
# ----> 2 g = it.next()
#       3 g.groups()
#
# AttributeError: 'callable_iterator' object has no attribute 'next'
