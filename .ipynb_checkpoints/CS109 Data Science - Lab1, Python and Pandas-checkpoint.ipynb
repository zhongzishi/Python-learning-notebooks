# %% [markdown]
# # Python and Modules

# %% [markdown]
# Quick settings and introductions about modules

# %%
# % sign here with command means we will display figures inline instead of in a new window
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
#sets up pandas table display
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.notebook_repr_html', True)
import seaborn as sns #sets up styles and gives us more plotting options

# %%
u_cols = ['user_id','age','sex','occupation','zip_code']
users = pd.read_csv(r'http://files.grouplens.org/datasets/movielens/ml-100k/u.user',sep='|',names=u_cols)
users.tail()
# Out:
#      user_id  age sex     occupation zip_code
# 938      939   26   F        student    33319
# 939      940   32   M  administrator    02215
# 940      941   20   M        student    97229
# 941      942   48   F      librarian    78209
# 942      943   22   M        student    77841

# %%
m_cols = ['movie_id','title','release_date','video_release_date','imdb_url']
movies = pd.read_csv(r'http://files.grouplens.org/datasets/movielens/ml-100k/u.item',sep='|',names=m_cols,usecols=range(5))
movies.head()
# Out:
#    movie_id              title release_date  video_release_date                                           imdb_url
# 0         1   Toy Story (1995)  01-Jan-1995                 NaN  http://us.imdb.com/M/title-exact?Toy%20Story%2...
# 1         2   GoldenEye (1995)  01-Jan-1995                 NaN  http://us.imdb.com/M/title-exact?GoldenEye%20(...
# 2         3  Four Rooms (1995)  01-Jan-1995                 NaN  http://us.imdb.com/M/title-exact?Four%20Rooms%...
# 3         4  Get Shorty (1995)  01-Jan-1995                 NaN  http://us.imdb.com/M/title-exact?Get%20Shorty%...
# 4         5     Copycat (1995)  01-Jan-1995                 NaN  http://us.imdb.com/M/title-exact?Copycat%20(1995)

# %%
print(movies.dtypes,'\n',movies.describe())
# Out:
# movie_id                int64
# title                  object
# release_date           object
# video_release_date    float64
# imdb_url               object
# dtype: object
#            movie_id  video_release_date
# count  1682.000000                 0.0
# mean    841.500000                 NaN
# std     485.695893                 NaN
# min       1.000000                 NaN
# 25%     421.250000                 NaN
# 50%     841.500000                 NaN
# 75%    1261.750000                 NaN
# max    1682.000000                 NaN

# %%
users.occupation.head()
x=set(users.occupation)
x
# Out:
# {'administrator',
#  'artist',
#  'doctor',
#  'educator',
#  'engineer',
#  'entertainment',
#  'executive',
#  'healthcare',
#  'homemaker',
#  'lawyer',
#  'librarian',
#  'marketing',
#  'none',
#  'other',
#  'programmer',
#  'retired',
#  'salesman',
#  'scientist',
#  'student',
#  'technician',
#  'writer'}

# %%
testColumns = ['occupation','sex']
users[testColumns].head()
# Out:
#    occupation sex
# 0  technician   M
# 1       other   F
# 2      writer   M
# 3  technician   M
# 4       other   F

# %%
print(users.iloc[3])
# Out:
# user_id                4
# age                   24
# sex                    M
# occupation    technician
# zip_code           43537
# Name: 3, dtype: object

# %%
oldusers = users[users.age > 25]
oldusers.count()
# Out:
# user_id       671
# age           671
# sex           671
# occupation    671
# zip_code      671
# dtype: int64

# %%
oldmales = users[(users.age == 40) & (users.sex == 'M')]
oldmales.count()
# Out:
# user_id       14
# age           14
# sex           14
# occupation    14
# zip_code      14
# dtype: int64

# %%
femaleProgrammer = users[(users.sex == 'F') & (users.occupation == 'programmer')]
femaleProgrammer.age.mean()
# Out:
# 32.166666666666664

# %%
ratings = pd.read_csv(r'http://files.grouplens.org/datasets/movielens/ml-100k/u.data',sep='\t',names=['user_id','movie_id','rating','timestamp'])
ratings.head()
# Out:
#    user_id  movie_id  rating  timestamp
# 0      196       242       3  881250949
# 1      186       302       3  891717742
# 2       22       377       1  878887116
# 3      244        51       2  880606923
# 4      166       346       1  886397596

# %%
grouped_data = ratings.rating.groupby(ratings.movie_id)
average_ratings = grouped_data.mean()
print(average_ratings.head())
# Out:
# movie_id
# 1    3.878319
# 2    3.206107
# 3    3.033333
# 4    3.550239
# 5    3.302326
# Name: rating, dtype: float64

# %%
maximum_rating = average_ratings.max()
good_movie_ids = average_ratings[average_ratings == maximum_rating].index
print(good_movie_ids)
# Out:
# Int64Index([814, 1122, 1189, 1201, 1293, 1467, 1500, 1536, 1599, 1653], dtype='int64', name='movie_id')

# %%
print(movies[movies.movie_id.isin(good_movie_ids)].title)
# Out:
# 813                         Great Day in Harlem, A (1994)
# 1121                       They Made Me a Criminal (1939)
# 1188                                   Prefontaine (1997)
# 1200           Marlene Dietrich: Shadow and Light (1996)
# 1292                                      Star Kid (1997)
# 1466                 Saint of Fort Washington, The (1993)
# 1499                            Santa with Muscles (1996)
# 1535                                 Aiqing wansui (1994)
# 1598                        Someone Else's America (1995)
# 1652    Entertaining Angels: The Dorothy Day Story (1996)
# Name: title, dtype: object

# %%
ratingscount = grouped_data.count()
#print(ratingscount)
print(ratingscount[average_ratings == maximum_rating])
# Out:
# movie_id
# 814     1
# 1122    1
# 1189    3
# 1201    1
# 1293    3
# 1467    2
# 1500    2
# 1536    1
# 1599    1
# 1653    1
# Name: rating, dtype: int64

# %%
newgrouped_data = ratings.rating.groupby(ratings.user_id)
average_ratings = newgrouped_data.mean()
average_ratings.head()
# Out:
# user_id
# 1    3.610294
# 2    3.709677
# 3    2.796296
# 4    4.333333
# 5    2.874286
# Name: rating, dtype: float64

# %%
new_occupation_data = users.sex.groupby(users['occupation'])
new_occupation_data.count()
# Out:
# occupation
# administrator     79
# artist            28
# doctor             7
# educator          95
# engineer          67
# entertainment     18
# executive         32
# healthcare        16
# homemaker          7
# lawyer            12
# librarian         51
# marketing         26
# none               9
# other            105
# programmer        66
# retired           14
# salesman          12
# scientist         31
# student          196
# technician        27
# writer            45
# Name: sex, dtype: int64

# %%
male_dominant_occupation = new_occupation_data.apply(lambda f:sum(f =='M')>sum(f=='F'))
print(male_dominant_occupation)
# Out:
# occupation
# administrator     True
# artist            True
# doctor            True
# educator          True
# engineer          True
# entertainment     True
# executive         True
# healthcare       False
# homemaker        False
# lawyer            True
# librarian        False
# marketing         True
# none              True
# other             True
# programmer        True
# retired           True
# salesman          True
# scientist         True
# student           True
# technician        True
# writer            True
# Name: sex, dtype: bool

# %%
import urllib.request
url = "https://www.crummy.com/software/BeautifulSoup"
source = urllib.request.urlopen(url).read().decode('utf-8')
print('Alice' in source)
print(source.count('Soup'))
position = source.find('alien video games')
print(position)
print(source[position:position + len('alien video games')])
# Out:
# False
# 42
# 1639
# alien video games

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(source,'lxml')
#print(soup.prettify())
first_tag = soup.findAll('a')
#first_tag.get('href')
link_list = [i.get('href') for i in first_tag]
link_list
# Out:
# ['bs4/download/',
#  '#Download',
#  'bs4/doc/',
#  '#HallOfFame',
#  'https://code.launchpad.net/beautifulsoup',
#  'https://groups.google.com/forum/?fromgroups#!forum/beautifulsoup',
#  'http://www.candlemarkandgleam.com/shop/constellation-games/',
#  'http://constellation.crummy.com/Constellation%20Games%20excerpt.html',
#  'https://groups.google.com/forum/?fromgroups#!forum/beautifulsoup',
#  'https://bugs.launchpad.net/beautifulsoup/',
#  'http://lxml.de/',
#  'http://code.google.com/p/html5lib/',
#  'bs4/doc/',
#  None,
#  'bs4/download/',
#  'http://www.crummy.com/software/BeautifulSoup/bs3/documentation.html',
#  'download/3.x/BeautifulSoup-3.2.1.tar.gz',
#  None,
#  'http://www.nytimes.com/2007/10/25/arts/design/25vide.html',
#  'https://github.com/reddit/reddit/blob/85f9cff3e2ab9bb8f19b96acd8da4ebacc079f04/r2/r2/lib/media.py',
#  'http://www.harrowell.org.uk/viktormap.html',
#  'http://svn.python.org/view/tracker/importer/',
#  'http://www2.ljworld.com/',
#  'http://www.b-list.org/weblog/2010/nov/02/news-done-broke/',
#  'http://esrl.noaa.gov/gsd/fab/',
#  'http://laps.noaa.gov/topograbber/',
#  'http://groups.google.com/group/beautifulsoup/',
#  'https://launchpad.net/beautifulsoup',
#  'https://code.launchpad.net/beautifulsoup/',
#  'https://bugs.launchpad.net/beautifulsoup/',
#  '/source/software/BeautifulSoup/index.bhtml',
#  '/self/',
#  '/self/contact.html',
#  'http://creativecommons.org/licenses/by-sa/2.0/',
#  'http://creativecommons.org/licenses/by-sa/2.0/',
#  'http://www.crummy.com/',
#  'http://www.crummy.com/software/',
#  'http://www.crummy.com/software/BeautifulSoup/']

# %%
external_links = []
for l in link_list:
    if l is not None and l[:4] == 'http' and l[-4:] == 'html':
        external_links.append(l)
external_links
# Out:
# ['http://constellation.crummy.com/Constellation%20Games%20excerpt.html',
#  'http://www.crummy.com/software/BeautifulSoup/bs3/documentation.html',
#  'http://www.nytimes.com/2007/10/25/arts/design/25vide.html',
#  'http://www.harrowell.org.uk/viktormap.html']

# %%
[j for j in link_list if j is not None and j.startswith('http') ]
# Out:
# ['https://code.launchpad.net/beautifulsoup',
#  'https://groups.google.com/forum/?fromgroups#!forum/beautifulsoup',
#  'http://www.candlemarkandgleam.com/shop/constellation-games/',
#  'http://constellation.crummy.com/Constellation%20Games%20excerpt.html',
#  'https://groups.google.com/forum/?fromgroups#!forum/beautifulsoup',
#  'https://bugs.launchpad.net/beautifulsoup/',
#  'http://lxml.de/',
#  'http://code.google.com/p/html5lib/',
#  'http://www.crummy.com/software/BeautifulSoup/bs3/documentation.html',
#  'http://www.nytimes.com/2007/10/25/arts/design/25vide.html',
#  'https://github.com/reddit/reddit/blob/85f9cff3e2ab9bb8f19b96acd8da4ebacc079f04/r2/r2/lib/media.py',
#  'http://www.harrowell.org.uk/viktormap.html',
#  'http://svn.python.org/view/tracker/importer/',
#  'http://www2.ljworld.com/',
#  'http://www.b-list.org/weblog/2010/nov/02/news-done-broke/',
#  'http://esrl.noaa.gov/gsd/fab/',
#  'http://laps.noaa.gov/topograbber/',
#  'http://groups.google.com/group/beautifulsoup/',
#  'https://launchpad.net/beautifulsoup',
#  'https://code.launchpad.net/beautifulsoup/',
#  'https://bugs.launchpad.net/beautifulsoup/',
#  'http://creativecommons.org/licenses/by-sa/2.0/',
#  'http://creativecommons.org/licenses/by-sa/2.0/',
#  'http://www.crummy.com/',
#  'http://www.crummy.com/software/',
#  'http://www.crummy.com/software/BeautifulSoup/']

# %%
h3 = soup.find("h3")
print(h3.string)
# Out:
# Beautiful Soup 3

# %%
hall_tag = soup.find('ul')
tmp = [l for l in hall_tag.children]
test =  ["".join(str(a) for a in sublist) for sublist in tmp]
print('\n'.join(test))
# Out:
# <a href="http://www.nytimes.com/2007/10/25/arts/design/25vide.html">"Movable
#  Type"</a>, a work of digital art on display in the lobby of the New
#  York Times building, uses Beautiful Soup to scrape news feeds.
#
#
# Reddit uses Beautiful Soup to <a href="https://github.com/reddit/reddit/blob/85f9cff3e2ab9bb8f19b96acd8da4ebacc079f04/r2/r2/lib/media.py">parse
# a page that's been linked to and find a representative image</a>.
#
#
# Alexander Harrowell uses Beautiful Soup to <a href="http://www.harrowell.org.uk/viktormap.html">track the business
#  activities</a> of an arms merchant.
#
#
# The developers of Python itself used Beautiful Soup to <a href="http://svn.python.org/view/tracker/importer/">migrate the Python
# bug tracker from Sourceforge to Roundup</a>.
#
#
# The <a href="http://www2.ljworld.com/">Lawrence Journal-World</a>
# uses Beautiful Soup to <a href="http://www.b-list.org/weblog/2010/nov/02/news-done-broke/">gather
# statewide election results</a>.
#
#
# The <a href="http://esrl.noaa.gov/gsd/fab/">NOAA's Forecast
# Applications Branch</a> uses Beautiful Soup in <a href="http://laps.noaa.gov/topograbber/">TopoGrabber</a>, a script for
# downloading "high resolution USGS datasets."

# %%
url = 'http://www.indeed.com/jobs?q=data+scientist&l='
source = urllib.request.urlopen(url).read().decode('UTF-8')
bs_tree = BeautifulSoup(source,'lxml')
job_count_string = bs_tree.find(id = 'searchCount').contents[0] #first child node of bs object: id = 'searchCount'
job_count_string = job_count_string.split()[-1] #split by space then take the last piece
print("Search yielded %s hits" % (job_count_string))
# Out:
# Search yielded 23,559 hits

# %%
job_count_digits = [int(d) for d in job_count_string if d.isdigit()]
job_count = np.sum([digit*(10**exponent) for digit,exponent in zip(job_count_digits[::-1],range(len(job_count_digits)))])
print(job_count_digits)
print(job_count)
# Out:
# [2, 3, 5, 5, 9]
# 23559

# %%
import time
num_pages = int(np.ceil(job_count/10))
base_url = 'http://www.indeed.com'
job_links = []
for i in range(1):
    if i%10 == 0:
        print(num_pages - i)
    url = 'http://www.indeed.com/jobs?q=data+scientist&start=' + str(i*10)
    html_page = urllib.request.urlopen(url).read()
    bs_tree = BeautifulSoup(html_page,'lxml')
    job_link_area = bs_tree.find(id = 'resultsCol')
    job_postings = job_link_area.find_all('div')
    job_postings = [jp for jp in job_postings if not jp.get("class") is None
                   and ''.join(jp.get('class')) == "rowresult"]
    job_ids = [jp.get('data-jk') for jp in job_postings]
    #print(job_ids)
    for id in job_ids:
        job_links.append(base_url + '/rc/clk?jk=' + id)
    time.sleep(1)
    
    print("number of job found: ",len(job_links))
    print(job_links)
# Out:
# 2356
# number of job found:  12
# ['http://www.indeed.com/rc/clk?jk=224dc9bcdde1f855', 'http://www.indeed.com/rc/clk?jk=293a1db47cfb7b74', 'http://www.indeed.com/rc/clk?jk=ff04082985a54f44', 'http://www.indeed.com/rc/clk?jk=5d086556de87706d', 'http://www.indeed.com/rc/clk?jk=0be3100a047d8270', 'http://www.indeed.com/rc/clk?jk=87d4e1b73c5090a5', 'http://www.indeed.com/rc/clk?jk=5002040cb0697713', 'http://www.indeed.com/rc/clk?jk=edc2796ec2610de4', 'http://www.indeed.com/rc/clk?jk=0d63c8d24c385ff6', 'http://www.indeed.com/rc/clk?jk=f6c72882af0f66f3', 'http://www.indeed.com/rc/clk?jk=52f486aa93db568a', 'http://www.indeed.com/rc/clk?jk=2072d942741d5e13']

# %%
#import pickle
#with open(r'c:\users\zishi\lab1.pkl','wb') as f:
#    pickle.dump(job_links,f)
#with open(r'c:\users\zishi\lab1.pkl','rb') as f:
#    job_links = pickle.load(f)
#print(job_links)

import json
#with open(r'c:\users\zishi\lab1.json','w') as f:
#    json.dump(job_links,f)
with open(r'c:\users\zishi\lab1.json','r') as f:
    job_links = json.load(f)

# %%
a = {'a': 1, 'b':2, 'c':3}
print(a.keys())
print(a.values())
for k,v in zip(a.keys(),a.values()):
    print(k,v)
# Out:
# dict_keys(['a', 'b', 'c'])
# dict_values([1, 2, 3])
# a 1
# b 2
# c 3

# %%
stuff_i_like = ['burger', 'sushi', 'sweet potato fries', 'BBQ','beer']
found_happy_hours = []
my_happy_hours = []
url = 'https://www.downtownla.com/explore/dining-nightlife/happy-hour-finder'
source = urllib.request.urlopen(url).read()
table = BeautifulSoup(source)
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en"> <![endif]--><!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en"> <![endif]--><!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en"> <![endif]--><!--[if IE 9]>    <html class="no-js ie9 oldie" lang="en"> <![endif]--><!--[if gt IE 9]><!--><html class="no-js ie" lang="en"> <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="EB9CEE9F7D7F6AC0DB0E002984943553" name="msvalidate.01"/>
# <meta content="sgJDyR8AMYtC7EbNE_xCV0ZIbIaRtkU8lphhthS5F5A" name="google-site-verification"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/>
# <link href="http://www.downtownla.com/" hreflang="en-us" rel="alternate"/>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/jquery/1.12.4/jquery.min.js"></script>
# <base href="https://www.downtownla.com/explore/dining-nightlife/happy-hour-finder"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="DowntownLA.com is proudly brought to you by the Downtown Center Business Improvement District. A coalition of nearly 1,700 property owners in the Central Business District" name="description"/>
# <meta content="Proof Interactive" name="generator"/>
# <title>Downtown LA - Happy Hour Finder</title>
# <link href="https://www.downtownla.com/component/search/?Itemid=271&amp;format=opensearch" rel="search" title="Search Downtown LA" type="application/opensearchdescription+xml"/>
# <meta content="Downtown LA - Happy Hour Finder" property="og:title"/>
# <meta content="DowntownLA.com is proudly brought to you by the Downtown Center Business Improvement District. A coalition of nearly 1,700 property owners in the Central Business District" property="og:description"/>
# <meta content="https://www.downtownla.com/favicons/social-260x260.png" property="og:image"/>
# <meta content="https://www.downtownla.com/explore/dining-nightlife/happy-hour-finder" property="og:url"/>
# <meta content="website" property="og:type"/>
# <meta content="website" name="twitter:card"/>
# <meta content="https://www.downtownla.com/explore/dining-nightlife/happy-hour-finder" name="twitter:url"/>
# <meta content="Downtown LA - Happy Hour Finder" name="twitter:title"/>
# <meta content="DowntownLA.com is proudly brought to you by the Downtown Center Business Improvement District. A coalition of nearly 1,700 property owners in the Central Business District" name="twitter:description"/>
# <meta content="https://www.downtownla.com/favicons/social-260x260.png" name="twitter:image"/>
# <link href="/favicons/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/favicons/apple-touch-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="/favicons/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/favicons/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/favicons/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="/favicons/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="/favicons/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="/favicons/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="/favicons/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/favicons/favicon-194x194.png" rel="icon" sizes="194x194" type="image/png"/>
# <link href="/favicons/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="/favicons/android-chrome-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
# <link href="/favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/favicons/manifest.json" rel="manifest"/>
# <link color="#8c8c8c" href="/favicons/safari-pinned-tab.svg" rel="mask-icon"/>
# <link href="/favicons/favicon.ico" rel="shortcut icon"/>
# <meta content="Downtown LA - Happy Hour Finder" name="apple-mobile-web-app-title"/>
# <meta content="Downtown LA - Happy Hour Finder" name="application-name"/>
# <meta content="#ffffff" name="msapplication-TileColor"/>
# <meta content="/favicons/mstile-144x144.png" name="msapplication-TileImage"/>
# <meta content="/favicons/browserconfig.xml" name="msapplication-config"/>
# <meta content="#8c8c8c" name="theme-color"/>
# <meta content="DowntownLA.com is proudly brought to you by the Downtown Center Business Improvement District. A coalition of nearly 1,700 property owners in the Central Business District" name="msapplication-tooltip"/>
# <meta content="Downtown LA - Happy Hour Finder" name="application-name"/>
# <link href="https://www.downtownla.com/index.php?option=com_xmap&amp;sitemap=1&amp;view=xml" rel="sitemap" title="Sitemap" type="application/xml"/>
# <link href="/min/g=css&amp;1489514644&amp;v=2" rel="stylesheet"/><!--[if (gte IE 6)&(lte IE 9)]>
# <script src="/templates/js/libs/modernizr.min.js"></script>
# <![endif]-->
# <!--[if IE]>
# <link rel=stylesheet href='/min/g=ie&amp;1466626790'>
# <style type="text/css" >
# html {
#   filter: expression(document.execCommand("BackgroundImageCache", false, true));
# }
# </style>
# <![endif]-->
# <script type="text/javascript">
#     window.smartlook||(function(d) {
#     var o=smartlook=function(){ o.api.push(arguments)},h=d.getElementsByTagName('head')[0];
#     var c=d.createElement('script');o.api=new Array();c.async=true;c.type='text/javascript';
#     c.charset='utf-8';c.src='//rec.smartlook.com/recorder.js';h.appendChild(c);
#     })(document);
#     smartlook('init', '702e27f569dcdc6bea309dee533676a2e7fca6b3');
# </script>
# </head>
# <body class=" explore dining-nightlife happy-hour-finder itemid-271 view-businesses option-com_dcbid_membermanager lang-en-gb direction-ltr menu_parent-271 group-0">
# <!-- Google Tag Manager -->
# <noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-52H452" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0], j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f); })(window,document,'script','dataLayer','GTM-52H452');</script>
# <!-- End Google Tag Manager -->
# <!-- ga Tag -->
# <script>
# (function(b,o,i,l,e,r){b.GoogleAnalyticsObject=l;b[l]||(b[l]=
# function(){(b[l].q=b[l].q||[]).push(arguments)});b[l].l=+new Date;
# e=o.createElement(i);r=o.getElementsByTagName(i)[0];
# e.src='https://www.google-analytics.com/analytics.js';
# r.parentNode.insertBefore(e,r)}(window,document,'script','ga'));
# ga('create','UA-69671207-1','auto');ga('send','pageview');
# </script>
# <!-- End ga Tag -->
# <!-- Quantcast Tag -->
# <script type="text/javascript">
# var _qevents=_qevents||[];(function(){var elem=document.createElement('script');elem.src=(document.location.protocol=="https:"?"https://secure":"http://edge")+".quantserve.com/quant.js";elem.async=true;elem.type="text/javascript";var scpt=document.getElementsByTagName('script')[0];scpt.parentNode.insertBefore(elem,scpt)})();_qevents.push({qacct:"p-93RVj0Mb0lDes"});
# </script>
# <noscript>
# <div style="display:none;"> <img alt="Quantcast" border="0" height="1" src="//pixel.quantserve.com/pixel/p-93RVj0Mb0lDes.gif" width="1"/> </div>
# </noscript>
# <!-- End Quantcast tag -->
# <div id="wrapper">
# <div id="cover"> </div>
# <div class=" push" id="wrapper_site">
# <div id="wrapper_head">
# <div id="head">
# <!-- <img id="logo_print" src="/templates/images/logo_print.jpg" width="135" height="28" /> -->
# <a href="/" id="logo">
# <p><strong>Downtown LA - Happy Hour Finder</strong></p>
# </a>
# <div class="open">
# <a class="menu" href="#navWrap" id="navBtn">
# <span class="navicon">
# <div class="hamburger" id="hamburger1"></div>
# <div class="hamburger" id="hamburger2"></div>
# <div class="hamburger" id="hamburger3"></div>
# </span>
# <span class="text">Menu</span>
# </a>
# </div>
# <div class="panel" id="navWrap" role="navigation">
# <form action="/explore/dining-nightlife/happy-hour-finder" method="post">
# <div class="mod_search">
# <input class="inputbox" id="mod-search-searchword" maxlength="200" name="searchword" onblur="if (this.value=='') this.value='Search ...';" onfocus="if (this.value=='Search ...') this.value='';" size="20" type="text" value="Search ..."/><input class="button" onclick="this.form.searchword.focus();" type="submit" value="Search"/> <input name="task" type="hidden" value="search"/>
# <input name="option" type="hidden" value="com_search"/>
# <input name="Itemid" type="hidden" value="212"/>
# </div>
# </form>
# <ul class="menumain">
# <li class="item-101"><a href="/"><span>Home</span></a></li><li class="item-223 active deeper parent"><a href="/explore"><span>Explore</span></a><ul><li class="item-260 deeper parent"><a href="/explore/entertainment-arts-culture"><span><strong>Entertainment, </strong>Arts &amp; Culture</span></a><ul><li class="item-412 parent"><a href="/explore/entertainment-arts-culture/sports"><span>Sports</span></a></li><li class="item-413 parent"><a href="/explore/entertainment-arts-culture/theatre-music"><span>Theatre &amp; Music</span></a></li><li class="item-414 parent"><a href="/explore/entertainment-arts-culture/museums-galleries"><span>Museums &amp; Galleries</span></a></li><li class="item-410 parent"><a href="/explore/entertainment-arts-culture/parks-green-spaces"><span>Parks &amp; Green Spaces</span></a></li><li class="item-415 parent"><a href="/explore/entertainment-arts-culture/kids-family-activities"><span>Kids &amp; Family Activities</span></a></li></ul></li><li class="item-261 active deeper parent"><a href="/explore/dining-nightlife"><span>Dining &amp; Nightlife</span></a><ul><li class="item-271 current active"><a href="/explore/dining-nightlife/happy-hour-finder"><span>Happy Hour Finder</span></a></li><li class="item-272"><a href="/explore/dining-nightlife/restaurant-guide"><span>Restaurant Guide</span></a></li><li class="item-273 parent"><a href="/explore/dining-nightlife/nightlife"><span>Nightlife</span></a></li><li class="item-393 parent"><a href="/explore/dining-nightlife/dining"><span>Dining</span></a></li></ul></li><li class="item-262 deeper parent"><a href="/explore/getting-around"><span>Getting Around</span></a><ul><li class="item-275 parent"><a href="/explore/getting-around/find-a-business"><span>Find a Business</span></a></li><li class="item-404"><a href="/explore/getting-around/parking"><span>Parking</span></a></li><li class="item-400"><a href="/explore/getting-around/public-transit"><span>Public Transit</span></a></li></ul></li><li class="item-263 deeper parent"><a href="/explore/shopping"><span>Shopping </span></a><ul><li class="item-274 parent"><a href="/explore/shopping/directory"><span>Shopping Directory</span></a></li><li class="item-399"><a href="/explore/shopping/downtown-specials"><span>Downtown Specials</span></a></li></ul></li><li class="item-264 deeper parent"><a href="/explore/events"><span>Events</span></a><ul><li class="item-276"><a href="/about-us/programs-initiatives/community-events"><span>BID Events</span></a></li><li class="item-277"><a href="/calendar"><span>Calendar</span></a></li><li class="item-278"><a href="/explore/events/submit-an-event"><span>Submit an Event</span></a></li></ul></li><li class="item-433 deeper parent"><a href="/explore/stay"><span>Stay</span></a><ul><li class="item-265 parent"></li><li class="item-434"><a href="/explore/stay/suites-furnished-living"><span>Suites &amp; Furnished Living</span></a></li><li class="item-435"><a href="/explore/stay/luxury-living"><span>Luxury Living</span></a></li><li class="item-436"><a href="/explore/stay/boutique-trendy"><span>Boutique &amp; Trendy</span></a></li><li class="item-437"><a href="/explore/stay/classic-historic"><span>Classic &amp; Historic</span></a></li></ul></li></ul></li><li class="item-224 deeper parent"><a href="/do-biz"><span>Do Biz</span></a><ul><li class="item-279 deeper parent"><a href="/do-biz/find-space"><span>Find Space</span></a><ul><li class="item-370 parent"><a href="/do-biz/find-space/building-finder"><span>Building Finder</span></a></li><li class="item-392"><a href="/about-us/programs-initiatives/get-urban"><span>Get Urban</span></a></li></ul></li><li class="item-428 deeper parent"><a href="/do-biz/business-services"><span>Business Services</span></a><ul><li class="item-283 parent"><a href="/do-biz/business-services/marketing"><span>Marketing</span></a></li><li class="item-285"><a href="/about-us/programs-initiatives/economic-development"><span>Economic Development</span></a></li></ul></li><li class="item-282 dee ...
# <ul class="menutop">
# <li class="item-227"><a href="/about-us/contact"><span>Contact</span></a></li><li class="item-228"><a href="/calendar"><span>Calendar</span></a></li><li class="item-229"><a href="/maps"><span>Maps</span></a></li><li class="item-460 last"><a href="/blog"><span>Blog</span></a></li></ul>
# </div>
# </div>
# </div>
# <div id="wrapper_content">
# <div id="content">
# <div class="mod_crumbs">
# <div class="breadcrumbs_crumbs">
# <a class="pathway" href="/">Home</a> <span class="seperator">|</span> <a class="pathway" href="/explore">Explore</a> <span class="seperator">|</span> <a class="pathway" href="/explore/dining-nightlife">Dining &amp; Nightlife</a> <span class="seperator">|</span> <span>Happy Hour Finder</span><div class="clear_it"></div>
# </div>
# <div class="clear_it"></div></div>
# <div class="fullwidth" id="middle">
# <div class="blog businesses" itemscope="" itemtype="http://schema.org/LocalBusiness">
# <h1>
# 		Happy Hour Finder	</h1>
# <div class="wrapper_copy">
# <form class="controls" id="Filters">
# <fieldset>
# <select class="select-days"><option value="">All Days</option><option value=".sunday">Sunday</option><option value=".monday">Monday</option><option value=".tuesday">Tuesday</option><option value=".wednesday">Wednesday</option><option value=".thursday">Thursday</option><option selected="" value=".friday">Friday</option><option value=".saturday">Saturday</option></select> </fieldset><fieldset>
# <select class="select-time">
# <option value="">Any Time</option>
# <option value=".t1200am">12:00am</option><option value=".t100am">1:00am</option><option value=".t200am">2:00am</option><option value=".t300am">3:00am</option><option value=".t400am">4:00am</option><option value=".t500am">5:00am</option><option value=".t600am">6:00am</option><option value=".t700am">7:00am</option><option value=".t800am">8:00am</option><option value=".t900am">9:00am</option><option value=".t1000am">10:00am</option><option value=".t1100am">11:00am</option><option value=".t1200pm">12:00pm</option><option value=".t100pm">1:00pm</option><option value=".t200pm">2:00pm</option><option value=".t300pm">3:00pm</option><option value=".t400pm">4:00pm</option><option value=".t500pm">5:00pm</option><option value=".t600pm">6:00pm</option><option value=".t700pm">7:00pm</option><option value=".t800pm">8:00pm</option><option value=".t900pm">9:00pm</option><option value=".t1000pm">10:00pm</option><option value=".t1100pm">11:00pm</option> </select>
# </fieldset><fieldset>
# <select class="select-amenities"><option selected="" value="">Select Amenities</option><option value=".beer-wine">Beer &amp; Wine</option><option value=".catering-available">Catering available</option><option value=".comedy">Comedy</option><option value=".communal-seating">Communal seating</option><option value=".dj">DJ</option><option value=".dancing">Dancing</option><option value=".delivery">Delivery</option><option value=".dress-code">Dress Code</option><option value=".full-bar">Full Bar</option><option value=".live-music">Live Music</option><option value=".outdoor-seating">Outdoor Seating</option><option value=".performance">Performance</option><option value=".skyline-views">Skyline Views</option><option value=".take-out">Take Out</option></select> </fieldset><fieldset>
# <select class="select-neighborhoods"><option selected="" value="">All Neighborhoods</option><option value=".arts-district">Arts District</option><option value=".bunker-hill">Bunker Hill</option><option value=".central-city-east">Central City East</option><option value=".chinatown">Chinatown</option><option value=".city-west">City West</option><option value=".civic-center">Civic Center</option><option value=".el-pueblo">El Pueblo</option><option value=".fashion-district">Fashion District</option><option value=".figueroa-corridor">Figueroa Corridor</option><option value=".financial-district">Financial District</option><option value=".historic-downtown">Historic Downtown</option><option value=".jewelry-district">Jewelry District</option><option value=".little-tokyo">Little Tokyo</option><option value=".south-park">South Park</option></select> </fieldset>
# <button id="Reset">Clear Filters</button>
# </form>
# <div class="wrapper_items">
# <div class="items happy-hour container" id="items">
# <div class="item mix monday tuesday wednesday thursday friday t300pm t400pm t500pm t600pm t700pm beer-wine full-bar outdoor-seating skyline-views financial-district" id="item-266">
# <a href="/explore/dining-nightlife/happy-hour-finder/bunker-hill-bar-grill">
# <div class="img"><img src="/images/businesses/happyhour/photos/bunkerhh.40a1c7.png" width="100%"/></div> <div class="info">
# <h2 class="name">Weekday Happy Hour</h2>
# <h3 class="location">@ <span>Bunker Hill Bar &amp; Grill</span></h3>
# <h4 class="days">Monday - Friday</h4>
# <div class="hours">3:00 pm - 7:00 pm</div>
# <p>$5-$8 Starters, $9 Specialty Cocktails, $5 House Wine, House Cocktails and Beer</p>
# <small><span class="address">601 S Grand Ave. Los Angeles, CA 90017</span><span class="neighborhood" data-href="#">Financial District</span></small>
# </div>
# </a>
# </div>
# <div class="item mix monday tuesday wednesday thursday friday t200pm t300pm t400pm t500pm t600pm t700pm beer-wine full-bar take-out bunker-hill" id="item-370">
# <a href="/explore/dining-nightlife/happy-hour-finder/nick-stef-s-steakhouse-la">
# <div class="img"><img src="/images/businesses/happyhour/photos/n+s-happyhour-ad-800x1200-071416(1).64028c.jpg" width="100%"/></div> <div class="info">
# <h2 class="name">Weekday Happy Hour</h2>
# <h3 class="location">@ <span>Nick &amp; Stef's Steakhouse LA</span></h3>
# <h4 class="days">Monday - Friday</h4>
# <div class="hours">2:00 pm - 7:00 pm</div>
# <p>Bites and cocktails starting at $5</p>
# <small><span class="address">330 S Hope St. Los Angeles, CA 90071</span><span class="neighborhood" data-href="#">Bunker Hill</span></small>
# </div>
# </a>
# </div>
# <div class="item mix monday tuesday wednesday thursday friday t300pm t400pm t500pm t600pm t700pm full-bar bunker-hill" id="item-371">
# <a href="/explore/dining-nightlife/happy-hour-finder/noe-restaurant-bar">
# <div class="img"><img src="/images/businesses/happyhour/photos/noebar.194fc6.jpg" width="100%"/></div> <div class="info">
# <h2 class="name">Noe Bar Happy Hour</h2>
# <h3 class="location">@ <span>Noe Restaurant &amp; Bar</span></h3>
# <h4 class="days">Monday - Friday</h4>
# <div class="hours">3:00 pm - 7:00 pm</div>
# </p>
# <small><span class="address">251 S Olive St. Los Angeles, CA 90012</span><span class="neighborhood" data-href="#">Bunker Hill</span></small>
# </div>
# </a>
# </div>
# <div class="item mix monday t400pm t500pm t600pm t700pm t800pm t900pm beer-wine full-bar central-city-east" id="item-602">
# <a href="/explore/dining-nightlife/happy-hour-finder/yxta-cocina-mexicana">
# <div class="img"><img src="/images/businesses/happyhour/photos/hh.0c422e.jpg" width="100%"/></div> <div class="info">
# <h2 class="name">Monday Happy Hour</h2>
# <h3 class="location">@ <span>Yxta Cocina Mexicana</span></h3>
# <h4 class="days">Monday</h4>
# <div class="hours">4:00 pm - 9:00 pm</div>
# <p>$6 margaritas, $4 select beers, $5-9 bites </p>
# <small><span class="address">601 S Central Ave. Los Angeles, CA 90021</span><span class="neighborhood" data-href="#">Central City East</span></small>
# </div>
# </a>
# </div>
# <div class="item mix tuesday wednesday thursday friday saturday t400pm t500pm t600pm t700pm beer-wine full-bar central-city-east" id="item-602">
# <a href="/explore/dining-nightlife/happy-hour-finder/yxta-cocina-mexicana">
# <div class="img"><img src="/images/businesses/happyhour/photos/hh.e68dd6.jpg" width="100%"/></div> <div class="info">
# <h2 class="name">Tuesday - Saturday Happy Hour</h2>
# <h3 class="location">@ <span>Yxta Cocina Mexicana</span></h3>
# <h4 class="days">Tuesday, Wednesday, Thursday, Friday, Saturday</h4>
# <div class="hours">4:00 pm - 7:00 pm</div>
# <p>$6 margaritas, $4 select beers, $5-9 bites </p>
# <small><span class="address">601 S Central Ave. Los Angeles, CA 90021</span><span class="neighborhood" data-href="#">Central City East</span></small>
# </div>
# </a>
# </div>
# <div class="item mix monday tuesday wednesday thursday friday t400pm t500pm t600pm t700pm beer-wine full-bar take-out financial-district" id="item-960">
# <a href="/explore/dining-nightlife/happy-hour-finder/bar-kitchen">
# <div class="img"><img src="/images/businesses/happyhour/photos/entrance.4b19f2.jpg" width="100%"/></div> <div class="info">
# <h2 class="name">Bar &amp; Kitchen </h2>
# <h3 class="location">@ <span>Bar &amp; Kitchen</span></h3>
# <h4 class="days">Monday - Friday</h4>
# <div class="hours">4:00 pm - 7:00 pm</div>
# <p>Bar &amp; Kitchen is a new-American restaurant with influences of Spanish and farm-fresh local Californian cuisine. Matched to this, Bar &amp;...</p>
# <small><span class="address">819 S Flower St. Los Angeles, CA 90017</span><span class="neighborhood" data-href="#">Financial District</span></small>
# </div>
# </a>
# </div>
# <div class="item mix monday tuesday wednesday thursday friday t300pm t400pm t500pm t600pm t700pm take-out financial-district" id="item-966">
# <a href="/explore/dining-nightlife/happy-hour-finder/big-wangs-sports-bar">
# <div class="img"><img src="/images/businesses/happyhour/photos/bigwangs.69b1e7.jpg" width="100%"/></div> <div class="info">
# <h2 class="name">Big Wangs Sports Bar </h2>
# <h3 class="location">@ <span>Big Wangs Sports Bar</span></h3>
# <h4 class="days">Monday - Friday</h4>
# <div class="hours">3:00 pm - 7:00 pm</div>
# <p>3 big plasma screen TVs and a big screen projection screen, pool, jukebox</p>
# <small><span class="address">801 S Grand Ave. Los Angeles, CA 90017</span><span class="neighborhood" data-href="#">Financial District</span></small>
# </div>
# </a>
# </div>
# <div class="item mix monday tuesday wednesday thursday friday t330pm t430pm t530pm t630pm full-bar financial-district" id="item-969">
# <a href="/explore/dining-nightlife/happy-hour-finder/bonaventure-brewing-company">
# <div class="img"><img src="/images/businesses/happyhour/photos/bonaventurebrewing3.0492dc.jpg" width="100%"/></div> <div class="info">
# <h2 class="name">Bonaventure Brewing Company </h2>
# <h3 class="location">@ <span>Bonaventure Brewing Company</span></h3>
# <h4 class="days">Monday - Friday</h4>
# <div class="hours">3:30 pm - 6:30 pm</div>
# <p>Brewpub offering craft beers, American grub &amp; city skyline views from 4th-floor outdoor patio.</p>
# <small><span class="address">404 S Figueroa St. Los Angeles, CA 90071</span><span class="neighborhood" data-href="#">Financial District</span></small>
# </div>
# </a>
# </div>
# <div class="item mix monday tuesday wednesday thursday friday t400pm t500pm t600pm t700pm full-bar catering-available take-out outdoor-seating skyline-views financial-district" id="item-974">
# <a href="/explore/dining-nightlife/happy-hour-finder/border-grill">
# <div class="img"><img src="/images/businesses/happyhour/photos/marg.a981c8.jpg" width="100%"/></div> <div class="info">
# <h2 class="name">Monday through Friday</h2>
# <h3 class="location">@ <span>Border Grill</span></h3>
# <h4 class="days">Monday - Friday</h4>
# <div class="hours">4:00 pm - 7:00 pm</div>
# <p>$5 Beers, $7 Beer &amp; Shot, $3.50 Tacos, $6 Margaritas</p>
# <small><span class="address">445 S Figueroa St. Los Angeles, CA 90071</span><span class="neighborhood" data-href="#">Financial District</span></small>
# </div>
# </a>
# </div>
# <div class="item mix monday tuesday wednesday thursday friday t400pm t500pm t600pm t700pm t800pm beer-wine full-bar catering-available take-out outdoor-seating financial-district" id="item-1004">
# <a href="/explore/dining-nightlife/happy-hour-finder/chaya-downtown">
# <div class="img"><img src="/images/businesses/happyhour/photos/chayalogo.5da23b.jpg" width="100%"/></div> <div class="info">
# <h2 class="name">Weekday Happy Hour</h2>
# <h3 class="location">@ <span>Chaya Downtown</span></h3>
# <h4 class="days">Monday - Friday</h4>
# <div class="hours">4:00 pm - 8:00 pm</div>
# <p>Happy Hour in the bar, lounge &amp; patio.</p>
# <small><span class="address">525 S Flower St. Los Angeles, CA 90071</span><span class="neighborhood" data-href="#">Financial District</span></small>
# </div>
# </a>
# </div>
# <div class="item mix saturday t530pm t630pm t730pm beer-wine full-bar catering-available take-out outdoor-seating financial-district" id="item-1004">
# <a href="/explore/dining-nightlife/happy-hour-finder/chaya-downtown">
# <div class="img"><img src="/images/businesses/happyhour/photos/chayalogo.1c9f5a.jpg" width="100%"/></div> <div class="info">
# <h2 class="name">Saturday Happy Hour</h2>
# <h3 class="location">@ <span>Chaya Downtown</span></h3>
# <h4 class="days">Saturday</h4>
# <div class="hours">5:30 pm - 8:00 pm</div>
# <p>Happy Hour in the bar, lounge &amp; patio.</p>
# <small><span class="address">525 S Flower St. Los Angeles, CA 90071</span><span class="neighborhood" data-href="#">Financial District</span></small>
# </div>
# </a>
# </div>
# <div class="item mix sunday t500pm t600pm t700pm t800pm beer-wine full-bar catering-available take-out outdoor-seating financial-district" id="item-1004">
# <a href="/explore/dining-nightlife/happy-hour-finder/chaya-downtown">
# <div class="img"><img src="/images/businesses/happyhour/photos/chayalogo.897f20.jpg" width="100%"/></div> <div class="info">
# <h2 class="name">Sunday Happy Hour</h2>
# <h3 class="location">@ <span>Chaya Downtown</span></h3>
# <h4 class="days">Sunday</h4>
# <div class="hours">5:00 pm - 8:00 pm</div>
# <p>Happy Hour in the bar, lounge &amp; patio.</p>
# <small><span class="address">525 S Flower St. Los Angeles, CA 90071</span><span class="neighborhood" data-href="#">Financial District</span></small>
# </div>
# </a>
# </div>
# <div class="item mix monday wednesday thursday friday t300pm t400pm t500pm t600pm t700pm take-out outdoor-seating financial-district" id="item-1094">
# <a href="/explore/dining-nightlife/happy-hour-finder/mas-malo">
# <div class="img"><img src="/images/businesses/happyhour/photos/masmalohh.a55cb8.jpg" width="100%"/></div> <div class="info">
# <h2 class="name">Great Happy Hour</h2>
# <h3 class="location">@ <span>Mas Malo</span></h3>
# <h4 class="days">Monday, Wednesday, Thursday, Friday</h4>
# <div class="hours">3:00 pm - 7:00 pm</div>
# </p>
# <small><span class="address">515 W 7th St. Los Angeles, CA 90014</span><span class="neighborhood" data-href="#">Financial District</span></small>
# </div>
# </a>
# </div>
# <div class="item mix tuesday t400pm t500pm t600pm t700pm t800pm t900pm t1000pm t1100pm take-out outdoor-seating financial-district" id="item-1094">
# <a href="/explore/dining-nightlife/happy-hour-finder/mas-malo">
# <div class="img"><img src="/images/businesses/happyhour/photos/masmalotaco.19bb45.jpg" width="100%"/></div> <div class="info">
# <h2 class="name">Taco Tuesdays</h2>
# <h3 class="location">@ <span>Mas Malo</span></h3>
# <h4 class="days">Tuesday</h4>
# <div class="hours">4:00 pm - 11:00 pm</div>
# <p>$2 Tacos</p>
# <small><span class="address">515 W 7th St. Los Angeles, CA 90014</span><span class="neighborhood" data-href="#">Financial District</span></small>
# </div>
# </a>
# </div>
# <div class="item mix monday tuesday wednesday thursday friday t400pm t500pm t600pm t700pm full-bar financial-district" id="item-1187">
# <a href="/explore/dining-nightlife/happy-hour-finder/takami-sushi-robata-restaurant">
# <div class="img"><img src="/images/businesses/happyhour/photos/takamihh.0c9ef9.jpg" width="100%"/></div> <div class="info">
# <h2 class="name">Weekday Happy Hour</h2>
# <h3 class="location">@ <span>Takami Sushi &amp; Robata Restaurant</span></h3>
# <h4 class="days">Monday - Friday</h4>
# <div class="hours">4:00 pm - 7:00 pm</div>
# <p>Delicious hand-crafted cocktails, imported beers, full sake, wine, and liquor menu, sushi and Robata sampler plates, light bites-- all...</p>
# <small><span class="address">811 Wilshire Blvd. 21st Flr. Los Angeles, CA 90017</span><span class="neighborhood" data-href="#">Financial District</span></small>
# </div>
# </a>
# </div>
# <div class="item mix sunday saturday t500pm t600pm t700pm full-bar financial-district" id="item-1187">
# <a href="/explore/dining-nightlife/happy-hour-finder/takami-sushi-robata-restaurant">
# <div class="img"><img src="/images/businesses/happyhour/photos/takamihh.87abad.jpg" width="100%"/></div> <div class="info">
# <h2 class="name">Weekend Happy Hour</h2>
# <h3 class="location">@ <span>Takami Sushi &amp; Robata Restaurant</span></h3>
# <h4 class="days">Sunday, Saturday</h4>
# <div class="hours">5:00 pm - 7:00 pm</div>
# <p>Delicious hand-crafted cocktails, imported beers, full sake, wine, and liquor menu, sushi and Robata sampler plates, light bites-- all...</p>
# <small><span class="address">811 Wilshire Blvd. 21st Flr. Los Angeles, CA 90017</span><span class="neighborhood" data-href="#">Financial District</span></small>
# </div>
# </a>
# </div>
# <div class="item mix sunday monday tuesday wednesday thursday friday saturday t300pm t400pm t500pm t600pm full-bar financial-district" id="item-1213">
# <a href="/explore/dining-nightlife/happy-hour-finder/dublin-s-irish-pub">
# <div class="img"><img src="/images/businesses/happyhour/photos/dublins1.33a9c8.png" width="100%"/></div> <div class="info">
# <h2 class="name">Daily Happy Hour</h2>
# <h3 class="location">@ <span>Dublin's Irish Whiskey Pub</span></h3>
# <h4 class="days">Every Day</h4>
# <div class="hours">3:00 pm - 6:00 pm</div>
# <p>$4 Budweiser &amp; PBR</p>
# <small><span class="address">815 W 7th St. Los Angeles, CA 90017</span><span class="neighborhood" data-href="#">Financial District</span></small>
# </div>
# </a>
# </div>
# <div class="item mix monday tuesday wednesday thursday friday t400pm t500pm t600pm t700pm financial-district" id="item-1240">
# <a href="/explore/dining-nightlife/happy-hour-finder/figat7th">
# <div class="img"><img src="/images/businesses/happyhour/photos/fighh.505f24.jpg" width="100%"/></div> <div class="info">
# <h2 class="name">Weekday Happy Hour</h2>
# <h3 class="location">@ <span>FIGat7th</span></h3>
# <h4 class="days">Monday - Friday</h4>
# <div class="hours">4:00 pm - 7:00 pm</div>
# <p>Weekdays 4pm to close, experience signature items from your favorite FIGat7th eateries!  Check out the deals below AND check back regularly...</p>
# <small><span class="address">735 S Figueroa St. Los Angeles, CA 90017</span><span class="neighborhood" data-href="#">Financial District</span></small>
# </div>
# </a>
# </div>
# <div class="item mix sunday monday tuesday wednesday thursday friday saturday t300pm t400pm t500pm t600pm beer-wine full-bar catering-available communal-seating take-out outdoor-seating financial-district" id="item-1404">
# <a href="/explore/dining-nightlife/happy-hour-finder/city-tavern-downtown-los-angeles">
# <div class="img"><img src="/images/businesses/happyhour/photos/citytavernhh.85229c.jpg" width="100%"/></div> <div class="info">
# <h2 class="name">Hoppy Hour</h2>
# <h3 class="location">@ <span>City Tavern DTLA</span></h3>
# <h4 class="days">Every Day</h4>
# <div class="hours">3:00 pm - 6:00 pm</div>
# <p>$10 for 32 oz. of craft beer (served in a milk jug), $5 well cocktails, $6 house cocktails, and our signature refined comfort food</p>
# <small><span class="address">735 S Figueroa St. Ste. 133 Los Angeles, CA 90017</span><span class="neighborhood" data-href="#">Financial District</span></small>
# </div>
# </a>
# </div>
# <div class="item mix monday tuesday wednesday thursday friday t500pm t600pm t700pm t800pm historic-downtown" id="item-1524">
# <a href="/explore/dining-nightlife/happy-hour-finder/las-perlas">
# <div class="img"><img src="/images/businesses/happyhour/photos/lasperlas.4baa92.jpg" width="100%"/></div> <div class="info">
# <h2 class="name">Margarita Hour</h2>
# <h3 class="location">@ <span>Las Perlas</span></h3>
# <h4 class="days">Monday - Friday</h4>
# <div class="hours">5:00 pm - 8:00 pm</div>
# </p>
# <small><span class="address">107 E 6th St. Los Angeles, CA 90014</span><span class="neighborhood" data-href="#">Historic Downtown</span></small>
# </div>
# </a>
# </div>
# <div class="item mix monday tuesday wednesday thursday friday t300pm t400pm t500pm t600pm t700pm beer-wine full-bar catering-available take-out historic-downtown" id="item-1700">
# <a href="/explore/dining-nightlife/happy-hour-finder/artisan-house">
# <div class="img"><img src="/images/businesses/happyhour/photos/artisanhh.bbc808.jpg" width="100%"/></div> <div class="info">
# <h2 class="name">Weekday Happy Hour</h2>
# <h3 class="location">@ <span>Artisan House</span></h3>
# <h4 class="days">Monday - Friday</h4>
# <div class="hours">3:00 pm - 7:00 pm</div>
# <p>$5 Well Drinks, Draft Beer &amp; House Wine</p>
# <small><span class="address">600 S Main St. Los Angeles, CA 90014</span><span class="neighborhood" data-href="#">Historic Downtown</span></small>
# </div>
# </a>
# </div>
# <div class="item mix sunday monday tuesday wednesday thursday friday saturday t400pm t500pm t600pm full-bar catering-available outdoor-seating historic-downtown" id="item-1751">
# <a href="/explore/dining-nightlife/happy-hour-finder/preux-proper">
# <div class="img"><img src="/images/businesses/happyhour/photos/preuxbar2.3ad6bd.jpg" width="100%"/></div> <div class="info">
# <h2 class="name">Daily Happy Hour</h2>
# <h3 class="location">@ <span>Preux &amp; Proper </span></h3>
# <h4 class="days">Every Day</h4>
# <div class="hours">4:00 pm - 6:00 pm</div>
# </p>
# <small><span class="address">840 S Spring St. Los Angeles, CA 90014</span><span class="neighborhood" data-href="#">Historic Downtown</span></small>
# </div>
# </a>
# </div>
# <div class="item mix sunday monday tuesday wednesday thursday saturday t330am t430am t530am t630am t730am t830am t930am t1030am t1130am t1230pm t130pm t230pm t330pm t430pm t530pm beer-wine full-bar take-out little-tokyo" id="item-1991">
# <a href="/explore/dining-nightlife/happy-hour-finder/justice-urban-tavern">
# <div class="img"><img src="/images/businesses/happyhour/photos/justicehh.f92336.jpg" width="100%"/></div> <div class="info">
# <h2 class="name">Social Hour</h2>
# <h3 class="location">@ <span>Justice Urban Tavern</span></h3>
# <h4 class="days">Sunday, Monday, Tuesday, Wednesday, Thursday, Saturday</h4>
# <div class="hours">3:30 am - 6:00 pm</div>
# <p>Social Hour offers small bites, wine &amp; cocktails. </p>
# <small><span class="address">120 S Los Angeles St. Los Angeles, CA 90012</span><span class="neighborhood" data-href="#">Little Tokyo</span></small>
# </div>
# </a>
# </div>
# <div class="item mix monday tuesday wednesday thursday t300pm t400pm t500pm t600pm t700pm full-bar south-park" id="item-2025">
# <a href="/explore/dining-nightlife/happy-hour-finder/lucky-strike-lanes">
# <div class="img"><img src="/images/businesses/happyhour/photos/hhlucky.490343.jpg" width="100%"/></div> <div class="info">
# <h2 class="name">Happy Hour</h2>
# <h3 class="location">@ <span>Lucky Strike Lanes at L.A. LIVE</span></h3>
# <h4 class="days">Monday, Tuesday, Wednesday, Thursday</h4>
# <div class="hours">3:00 pm - 7:00 pm</div>
# <p>$4 Bud Light &amp; Coors Light, $5 Lucky Cocktail, $5 House Wine, 1/2 off Food Specials</p>
# <small><span class="address">800 W Olympic Blvd. Los Angeles, CA 90015</span><span class="neighborhood" data-href="#">South Park</span></small>
# </div>
# </a>
# </div>
# <div class="item mix monday tuesday wednesday thursday t1000pm t900pm t800pm t700pm t600pm t500pm t400pm t300pm t200pm t100pm t1200pm t1100am t1000am t900am t800am t700am t600am t500am t400am t300am t200am full-bar south-park" id="item-2025">
# <a href="/explore/dining-nightlife/happy-hour-finder/lucky-strike-lanes">
# <div class="img"><img src="/images/businesses/happyhour/photos/hhlucky.a28db4.jpg" width="100%"/></div> <div class="info">
# <h2 class="name">Late Night Happy Hour</h2>
# <h3 class="location">@ <span>Lucky Strike Lanes at L.A. LIVE</span></h3>
# <h4 class="days">Monday, Tuesday, Wednesday, Thursday</h4>
# <div class="hours">10:00 pm - 2:00 am</div>
# <p>$4 Bud Light &amp; Coors Light, $5 Lucky Cocktail, $5 House Wine, 1/2 off Food Specials</p>
# <small><span class="address">800 W Olympic Blvd. Los Angeles, CA 90015</span><span class="neighborhood" data-href="#">South Park</span></small>
# </div>
# </a>
# </div>
# <div class="item mix sunday monday tuesday wednesday thursday friday saturday t400pm t500pm t600pm south-park" id="item-2059">
# <a href="/explore/dining-nightlife/happy-hour-finder/fleming-s-prime-steakhouse">
# <div class="info">
# <h2 class="name">Daily Happy Hour</h2>
# <h3 class="location">@ <span>Fleming's Prime Steakhouse</span></h3>
# <h4 class="days">Every Day</h4>
# <div class="hours">4:00 pm - 6:00 pm</div>
# <p>5 selections for $6 each.</p>
# <small><span class="address">800 W Olympic Blvd. Los Angeles, CA 90015</span><span class="neighborhood" data-href="#">South Park</span></small>
# </div>
# </a>
# </div>
# <div class="item mix monday tuesday wednesday thursday friday t300pm t400pm t500pm t600pm south-park" id="item-2086">
# <a href="/explore/dining-nightlife/happy-hour-finder/yard-house">
# <div class="img"><img src="/images/businesses/happyhour/photos/yardhh.ec84bf.jpg" width="100%"/></div> <div class="info">
# <h2 class="name">Weekday Happy Hour</h2>
# <h3 class="location">@ <span>Yard House</span></h3>
# <h4 class="days">Monday - Friday</h4>
# <div class="hours">3:00 pm - 6:00 pm</div>
# <p>$1 Off Domestic Pints and Well Drinks, $4 Off Craft &amp; Import Half Yards, $6-$8 Bites</p>
# <small><span class="address">800 W Olympic Blvd. Los Angeles, CA 90015</span><span class="neighborhood" data-href="#">South Park</span></small>
# </div>
# </a>
# </div>
# <div class="item mix monday tuesday wednesday thursday friday t300pm t400pm t500pm t600pm beer-wine full-bar outdoor-seating south-park" id="item-2117">
# <a href="/explore/dining-nightlife/happy-hour-finder/tom-s-urban">
# <div class="img"><img src="/images/businesses/happyhour/photos/toms.daa916.jpg" width="100%"/></div> <div class="info">
# <h2 class="name">Beat The Clock</h2>
# <h3 class="location">@ <span>Tom's Urban</span></h3>
# <h4 class="days">Monday - Friday</h4>
# <div class="hours">3:00 pm - 6:00 pm</div>
# <p>Prices starting at $3 and rise every hour until 6pm. Guests are able to choose from 12 small plates including Ginger Chicken Potstickers,...</p>
# <small><span class="address">1011 S Figueroa St. Los Angeles, CA 90015</span><span class="neighborhood" data-href="#">South Park</span></small>
# </div>
# </a>
# </div>
# <div class="item mix sunday monday tuesday wednesday thursday t1000pm t900pm t800pm t700pm t600pm t500pm t400pm t300pm t200pm t100pm t1200pm t1100am t1000am t900am t800am t700am t600am t500am t400am t300am t200am t100am beer-wine full-bar outdoor-seating south-park" id="item-2117">
# <a href="/explore/dining-nightlife/happy-hour-finder/tom-s-urban">
# <div class="img"><img src="/images/businesses/happyhour/photos/toms.b5e401.jpg" width="100%"/></div> <div class="info">
# <h2 class="name">Beat The Clock - Late Night</h2>
# <h3 class="location">@ <span>Tom's Urban</span></h3>
# <h4 class="days">Sunday, Monday, Tuesday, Wednesday, Thursday</h4>
# <div class="hours">10:00 pm - 1:00 am</div>
# <p>Beginning at 10pm with prices starting at $5 and drop every hour until 1am. Guests are able to choose from 12 small plates including Ginger...</p>
# <small><span class="address">1011 S Figueroa St. Los Angeles, CA 90015</span><span class="neighborhood" data-href="#">South Park</span></small>
# </div>
# </a>
# </div>
# <div class="item mix sunday monday tuesday wednesday thursday friday saturday t300pm t400pm t500pm t600pm t700pm full-bar take-out outdoor-seating south-park" id="item-2128">
# <a href="/explore/dining-nightlife/happy-hour-finder/triple-8-china-bar-grill">
# <div class="img"><img src="/images/businesses/happyhour/photos/8logo.d40576.jpg" width="100%"/></div> <div class="info">
# <h2 class="name">Daily Happy Hour</h2>
# <h3 class="location">@ <span>Triple 8 China Bar &amp; Grill</span></h3>
# <h4 class="days">Every Day</h4>
# <div class="hours">3:00 pm - 7:00 pm</div>
# <p>$3-$7 Bites, $6 Well Drinks, $6 Wine and Saki</p>
# <small><span class="address">800 W Olympic Blvd. Ste. A-120 Los Angeles, CA 90015</span><span class="neighborhood" data-href="#">South Park</span></small>
# </div>
# </a>
# </div>
# <div class="item mix sunday monday tuesday wednesday thursday friday saturday t1100pm t1000pm t900pm t800pm t700pm t600pm t500pm t400pm t300pm t200pm t100pm t1200pm t1100am t1000am t900am t800am t700am t600am t500am t400am t300am t200am full-bar take-out outdoor-seating south-park" id="item-2128">
# <a href="/explore/dining-nightlife/happy-hour-finder/triple-8-china-bar-grill">
# <div class="img"><img src="/images/businesses/happyhour/photos/8logo.1689ca.jpg" width="100%"/></div> <div class="info">
# <h2 class="name">Daily Happy Hour</h2>
# <h3 class="location">@ <span>Triple 8 China Bar &amp; Grill</span></h3>
# <h4 class="days">Every Day</h4>
# <div class="hours">11:00 pm - 2:00 am</div>
# <p>$3-$7 Bites, $6 Well Drinks, $6 Wine and Saki</p>
# <small><span class="address">800 W Olympic Blvd. Ste. A-120 Los Angeles, CA 90015</span><span class="neighborhood" data-href="#">South Park</span></small>
# </div>
# </a>
# </div>
# <div class="item mix monday tuesday wednesday thursday friday t530pm t630pm beer-wine financial-district" id="item-2149">
# <a href="/explore/dining-nightlife/happy-hour-finder/bs-taqueria">
# <div class="img"><img src="/images/businesses/happyhour/photos/bstaqhh2.5c2fe1.jpg" width="100%"/></div> <div class="info">
# <h2 class="name">#NOBSHour </h2>
# <h3 class="location">@ <span>BS Taqueria</span></h3>
# <h4 class="days">Monday - Friday</h4>
# <div class="hours">5:30 pm - 7:00 pm</div>
# </p>
# <small><span class="address">514 W 7th St. Los Angeles, CA 90014</span><span class="neighborhood" data-href="#">Financial District</span></small>
# </div>
# </a>
# </div>
# <div class="item mix tuesday wednesday thursday friday saturday t400pm t500pm t600pm t700pm outdoor-seating financial-district" id="item-2159">
# <a href="/explore/dining-nightlife/happy-hour-finder/pitchoun-bakery-cafe">
# <div class="img"><img src="/images/businesses/happyhour/photos/pitch.12f766.jpg" width="100%"/></div> <div class="info">
# <h2 class="name">Happy Hour</h2>
# <h3 class="location">@ <span>Pitchoun Bakery &amp; Cafe</span></h3>
# <h4 class="days">Tuesday, Wednesday, Thursday, Friday, Saturday</h4>
# <div class="hours">4:00 pm - 7:00 pm</div>
# <p>Selection of charcuterie and cheese boards, housemade terrines and tapas with wine pairing suggestions. </p>
# <small><span class="address">545 S Olive St. Los Angeles, CA 90013</span><span class="neighborhood" data-href="#">Financial District</span></small>
# </div>
# </a>
# </div>
# <div class="item mix monday tuesday wednesday thursday friday t500pm t600pm full-bar outdoor-seating civic-center" id="item-2160">
# <a href="/explore/dining-nightlife/happy-hour-finder/redbird">
# <div class="img"><img src="/images/businesses/happyhour/photos/redbirdhh.5d5ba1.jpg" width="100%"/></div> <div class="info">
# <h2 class="name">Weekday Happy Hour</h2>
# <h3 class="location">@ <span>Redbird</span></h3>
# <h4 class="days">Monday - Friday</h4>
# <div class="hours">5:00 pm - 6:00 pm</div>
# <p></p>
# <small><span class="address">114 E 2nd St. Los Angeles, CA 90012</span><span class="neighborhood" data-href="#">Civic Center</span></small>
# </div>
# </a>
# </div>
# <div class="item mix monday tuesday wednesday thursday friday t400pm t500pm t600pm t700pm t800pm t900pm t1000pm take-out outdoor-seating financial-district" id="item-2164">
# <a href="/explore/dining-nightlife/happy-hour-finder/taste-figat7th">
# <div class="img"><img src="/images/businesses/happyhour/photos/happy-hour-logo-fig-color-logo-white-background-300x86(1).d81575.jpg" width="100%"/></div> <div class="info">
# <h2 class="name">Weekday Happy Hour</h2>
# <h3 class="location">@ <span>Taste FIGat7th</span></h3>
# <h4 class="days">Monday - Friday</h4>
# <div class="hours">4:00 pm - 10:00 pm</div>
# <p>Weekdays 4pm to close, experience signature items from your favorite FIGat7th eateries!  Check out the deals below AND check back regularly...</p>
# <small><span class="address">735 S Figueroa St. Los Angeles, CA 90017</span><span class="neighborhood" data-href="#">Financial District</span></small>
# </div>
# </a>
# </div>
# <div class="item mix monday tuesday wednesday thursday friday t330pm t430pm t530pm full-bar bunker-hill" id="item-2166">
# <a href="/explore/dining-nightlife/happy-hour-finder/vespaio">
# <div class="img"><img src="/images/businesses/happyhour/photos/vespahh.2ad73a.jpg" width="100%"/></div> <div class="info">
# <h2 class="name">Weekday Happy Hour</h2>
# <h3 class="location">@ <span>Vespaio</span></h3>
# <h4 class="days">Monday - Friday</h4>
# <div class="hours">3:30 pm - 6:00 pm</div>
# <p>Signature Cocktails, Craft &amp; Import Beers, Wines by the Glass, Small Plates</p>
# <small><span class="address">225 S Grand Ave. Los Angeles, CA 90012</span><span class="neighborhood" data-href="#">Bunker Hill</span></small>
# </div>
# </a>
# </div>
# <div class="item mix monday tuesday wednesday thursday friday t400pm t500pm t600pm t700pm full-bar historic-downtown" id="item-2185">
# <a href="/explore/dining-nightlife/happy-hour-finder/le-petit-paris">
# <div class="img"><img src="/images/businesses/happyhour/photos/lepetithappyhour.fffd47.jpg" width="100%"/></div> <div class="info">
# <h2 class="name">After Work Hours</h2>
# <h3 class="location">@ <span>Le Petit Paris</span></h3>
# <h4 class="days">Monday - Friday</h4>
# <div class="hours">4:00 pm - 7:00 pm</div>
# <p>Beer $5, Wine $7, Signature Cocktails &amp; Appetizers $9</p>
# <small><span class="address"> 418 S Spring St Los Angeles, CA 90013</span><span class="neighborhood" data-href="#">Historic Downtown</span></small>
# </div>
# </a>
# </div>
# <div class="item mix monday tuesday thursday friday t400pm t500pm t600pm t700pm t800pm t900pm live-music dj beer-wine full-bar outdoor-seating dancing historic-downtown" id="item-2186">
# <a href="/explore/dining-nightlife/happy-hour-finder/la-cita">
# <div class="img"><img src="/images/businesses/happyhour/photos/lacita.aa5513.jpg" width="100%"/></div> <div class="info">
# <h2 class="name">Daily Happy Hour </h2>
# <h3 class="location">@ <span>La Cita </span></h3>
# <h4 class="days">Monday, Tuesday, Thursday, Friday</h4>
# <div class="hours">4:00 pm - 9:00 pm</div>
# <p></p>
# <small><span class="address">336 S Hill St. Los Angeles, CA 90013</span><span class="neighborhood" data-href="#">Historic Downtown</span></small>
# </div>
# </a>
# </div>
# <div class="item mix sunday saturday t200pm t300pm t400pm t500pm t600pm t700pm t800pm t900pm live-music dj beer-wine full-bar outdoor-seating dancing historic-downtown" id="item-2186">
# <a href="/explore/dining-nightlife/happy-hour-finder/la-cita">
# <div class="img"><img src="/images/businesses/happyhour/photos/lacita.f41b4e.jpg" width="100%"/></div> <div class="info">
# <h2 class="name">Daily Happy Hour </h2>
# <h3 class="location">@ <span>La Cita </span></h3>
# <h4 class="days">Sunday, Saturday</h4>
# <div class="hours">2:00 pm - 9:00 pm</div>
# <p></p>
# <small><span class="address">336 S Hill St. Los Angeles, CA 90013</span><span class="neighborhood" data-href="#">Historic Downtown</span></small>
# </div>
# </a>
# </div>
# <div class="item mix wednesday t400pm t500pm t600pm t700pm t800pm t900pm live-music dj beer-wine full-bar outdoor-seating dancing historic-downtown" id="item-2186">
# <a href="/explore/dining-nightlife/happy-hour-finder/la-cita">
# <div class="img"><img src="/images/businesses/happyhour/photos/lacitahiphophh.ed40c0.jpg" width="100%"/></div> <div class="info">
# <h2 class="name">Hip Hop Happy Hour</h2>
# <h3 class="location">@ <span>La Cita </span></h3>
# <h4 class="days">Wednesday</h4>
# <div class="hours">4:00 pm - 9:00 pm</div>
# </p>
# ...
# <div class="img"><img src="/images/businesses/happyhour/photos/img-menu3.9564b4.jpg" width="100%"/></div> <div class="info">
# <h2 class="name">Hora Especial</h2>
# <h3 class="location">@ <span>Broken Spanish</span></h3>
# <h4 class="days">Monday, Tuesday, Wednesday, Thursday</h4>
# <div class="hours">5:30 pm - 7:00 pm</div>
# </p>
# <small><span class="address">1050 S Flower St. Los Angeles, CA 90015</span><span class="neighborhood" data-href="#">South Park</span></small>
# </div>
# </a>
# </div>
# <div class="item mix monday tuesday wednesday thursday t1200am arts-district" id="item-2244">
# <a href="/explore/dining-nightlife/happy-hour-finder/arts-district-brewing-company">
# <div class="img"><img src="/images/businesses/happyhour/photos/rainbeauadbselects-13-1-1280x720.2f26e2.jpg" width="100%"/></div> <div class="info">
# <h2 class="name">Happy Hour</h2>
# <h3 class="location">@ <span>Arts District Brewing Company </span></h3>
# <h4 class="days">Monday, Tuesday, Wednesday, Thursday</h4>
# <div class="hours">12:00 am - 12:00 am</div>
# <p>$5 House Beer</p>
# <small><span class="address"> 828 Traction Avenue Los Angeles, CA 90013</span><span class="neighborhood" data-href="#">Arts District</span></small>
# </div>
# </a>
# </div>
# <div class="item mix tuesday wednesday thursday friday t530pm t630pm beer-wine full-bar little-tokyo" id="item-2251">
# <a href="/explore/dining-nightlife/happy-hour-finder/simbal-restaurant">
# <div class="img"><img src="/images/businesses/happyhour/photos/simbalhh.620502.jpg" width="100%"/></div> <div class="info">
# <h2 class="name">Happy Hour</h2>
# <h3 class="location">@ <span>Simbal Restaurant</span></h3>
# <h4 class="days">Tuesday, Wednesday, Thursday, Friday</h4>
# <div class="hours">5:30 pm - 6:30 pm</div>
# <p>$7 Well Cocktails, $5 Draft Beer, $5 Wine, $9 Small Bites</p>
# <small><span class="address"> 319 E 2nd St Ste 202 Los Angeles, CA 90012</span><span class="neighborhood" data-href="#">Little Tokyo</span></small>
# </div>
# </a>
# </div>
# <div class="item mix sunday monday tuesday wednesday thursday friday saturday t500pm t600pm t700pm full-bar south-park" id="item-2252">
# <a href="/explore/dining-nightlife/happy-hour-finder/barcito">
# <div class="img"><img src="/images/businesses/happyhour/photos/barcitohh.2020ea.png" width="100%"/></div> <div class="info">
# <h2 class="name">Aperitivo Hour</h2>
# <h3 class="location">@ <span>Barcito</span></h3>
# <h4 class="days">Every Day</h4>
# <div class="hours">5:00 pm - 7:00 pm</div>
# <p>$8. Includes Hospitality and Snack Trio.</p>
# <small><span class="address"> 403 W 12th St Los Angeles, CA 90015</span><span class="neighborhood" data-href="#">South Park</span></small>
# </div>
# </a>
# </div>
# <div class="item mix monday tuesday wednesday thursday friday t300pm t400pm t500pm t600pm t700pm full-bar outdoor-seating skyline-views bunker-hill" id="item-2302">
# <a href="/explore/dining-nightlife/happy-hour-finder/pez-cantina">
# <div class="img"><img src="/images/businesses/happyhour/photos/pezhh.1525bf.jpg" width="100%"/></div> <div class="info">
# <h2 class="name">Weekday Happy Hour</h2>
# <h3 class="location">@ <span>Pez Cantina</span></h3>
# <h4 class="days">Monday - Friday</h4>
# <div class="hours">3:00 pm - 7:00 pm</div>
# <p>$7 Cocktails, Wine, Beer and Bites.</p>
# <small><span class="address"> 401 S Grand Ave Los Angeles, CA 90071</span><span class="neighborhood" data-href="#">Bunker Hill</span></small>
# </div>
# </a>
# </div>
# <div class="item mix sunday monday tuesday wednesday thursday friday saturday t300pm t400pm t500pm t600pm arts-district" id="item-2303">
# <a href="/explore/dining-nightlife/happy-hour-finder/cerveteca-dtla">
# <div class="img"><img src="/images/businesses/happyhour/photos/cervetecahh.cecb91.jpg" width="100%"/></div> <div class="info">
# <h2 class="name">Daily Happy Hour</h2>
# <h3 class="location">@ <span>Cerveteca DTLA </span></h3>
# <h4 class="days">Every Day</h4>
# <div class="hours">3:00 pm - 6:00 pm</div>
# <p>$1 Oysters, $7 LA Street Dog, $4 PBR "Tall Boy" and more.</p>
# <small><span class="address"> 923 E 3rd St Ste 109 Los Angeles, CA 90013</span><span class="neighborhood" data-href="#">Arts District</span></small>
# </div>
# </a>
# </div>
# <div class="item mix monday tuesday wednesday thursday friday t300pm t400pm t500pm t600pm t700pm beer-wine full-bar catering-available take-out historic-downtown" id="item-2329">
# <a href="/explore/dining-nightlife/happy-hour-finder/artisan-house">
# <div class="img"><img src="/images/businesses/happyhour/photos/artisanhh.bbc808.jpg" width="100%"/></div> <div class="info">
# <h2 class="name">Weekday Happy Hour</h2>
# <h3 class="location">@ <span>Artisan House</span></h3>
# <h4 class="days">Monday - Friday</h4>
# <div class="hours">3:00 pm - 7:00 pm</div>
# <p>$5 Well Drinks, Draft Beer &amp; House Wine</p>
# <small><span class="address">600 S Main St. Los Angeles, CA 90014</span><span class="neighborhood" data-href="#">Historic Downtown</span></small>
# </div>
# </a>
# </div>
# <div class="item mix monday tuesday wednesday thursday friday saturday t400pm t500pm t600pm t700pm beer-wine full-bar financial-district" id="item-2401">
# <a href="/explore/dining-nightlife/happy-hour-finder/brack-shop-tavern">
# <div class="img"><img src="/images/businesses/happyhour/photos/bsthh1.81a95f.jpg" width="100%"/></div> <div class="info">
# <h2 class="name">Happy Hour</h2>
# <h3 class="location">@ <span>Brack Shop Tavern</span></h3>
# <h4 class="days">Monday - Friday</h4>
# <div class="hours">4:00 pm - 7:00 pm</div>
# <p>$3-$5 food specials and $5-$6 drink specials.</p>
# <small><span class="address">525 West 7th St Los Angeles, CA 90014</span><span class="neighborhood" data-href="#">Financial District</span></small>
# </div>
# </a>
# </div>
# <div class="item mix sunday monday tuesday wednesday thursday friday saturday t300pm t400pm t500pm t600pm t700pm beer-wine full-bar historic-downtown" id="item-2417">
# <a href="/explore/dining-nightlife/happy-hour-finder/mezcalero">
# <div class="img"><img src="/images/businesses/happyhour/photos/mezhh.88ecb9.jpg" width="100%"/></div> <div class="info">
# <h2 class="name">Daily Happy Hour</h2>
# <h3 class="location">@ <span>Mezcalero</span></h3>
# <h4 class="days">Every Day</h4>
# <div class="hours">3:00 pm - 7:00 pm</div>
# <p>Join us for Happy Hour!</p>
# <small><span class="address">510 S Broadway Los Angeles, CA 90013</span><span class="neighborhood" data-href="#">Historic Downtown</span></small>
# </div>
# </a>
# </div>
# </div>
# </div>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/mixitup/2.1.10/jquery.mixitup.min.js"></script>
# <script type="text/javascript">
#
# 			dropdownFilter = {
# 				$filters: null,
# 				$reset: null,
# 				groups: [],
# 				outputArray: [],
# 				outputString: '',
#
# 				init: function(){
# 					var self = this;
#
#
# 					self.$filters = jQuery('#Filters');
# 					self.$reset = jQuery('#Reset');
# 					self.$container = jQuery('#items');
#
# 					self.$filters.find('fieldset').each(function(){
# 						self.groups.push({
# 							$dropdown: jQuery(this).find('select'),
# 							active: ''
# 						});
# 					});
#
# 					self.bindHandlers();
# 				},
#
# 				bindHandlers: function(){
# 					var self = this;
#
# 					self.$filters.on('change', 'select', function(e){
# 						e.preventDefault();
# 						self.parseFilters();
# 					});
#
# 					self.$reset.on('click', function(e){
# 						e.preventDefault();
# 						self.$filters.find('select').val('');
# 						self.parseFilters();
# 					});
# 				},
#
# 				parseFilters: function(){
# 					var self = this;
#
# 					for(var i = 0, group; group = self.groups[i]; i++){
# 						group.active = group.$dropdown.val();
# 					}
#
# 					self.concatenate();
# 				},
#
# 				concatenate: function(){
# 					var self = this;
#
# 					self.outputString = '';
#
# 					for(var i = 0, group; group = self.groups[i]; i++){
# 						self.outputString += group.active;
# 					}
#
# 					console.log(self.outputString);
#
# 					!self.outputString.length && (self.outputString = 'all');
#
# 					if(self.$container.mixItUp('isLoaded')){
# 						self.$container.mixItUp('filter', self.outputString);
# 					}
# 				}
# 			};
#
# 			jQuery(document).ready(function() {
#
# 				dropdownFilter.init();
#
# 				var container = jQuery('#items');
#
# 				container.mixItUp({
# 					controls: {
# 						enable: false
# 					},
# 					animation: {
# 						effects: 'fade scale',
# 						duration: 600,
# 						queueLimit: 10,
# 						reverseOut: true
# 					},
# 					layout: {
# 						containerClass: 'grid'
# 					},
# 					load: {
# 						filter: '.friday'
# 					},
# 					callbacks: {
# 						onMixFail: function(){
# 							//console.log('--> FAIL: No matches');
# 						},
# 						onMixStart: function(state, futureState){
# 							//console.log('--> onMixStart');
# 						},
# 						onMixLoad: function(state){
# 							//console.log('--> onMixLoad');
# 							//var items = $('.items .item').map(function() { return $(this).height(); }).get();
# 							//var items_maxHeight = Math.max.apply(null, items);
# 							//jQuery('.items .item').height(items_maxHeight);
# 							//jQuery('#items').mixItUp('filter', '.monday', false);
# 							//jQuery(".select-days").val('.friday');
# 						}
# 					}
# 				});
#
# 				container.mixItUp('changeLayout', {
# 					//containerClass: 'list'
# 				});
#
# 			});
#
# 		</script>
# </div>
# </div>
# </div>
# <div class="clear_it"></div>
# </div>
# </div>
# <div id="wrapper_featured">
# <div id="featured">
# <div class="mod_featuremenu"><ul class="menufeature">
# <li class="item-529"><a href="/explore/dining-nightlife/restaurant-guide"><span>Restaurant Guide</span><div class="menuimg" style="background-image:url(/images/menus/menu_restaurantguide.jpg);"></div></a></li><li class="item-530"><a href="/about-us/publications/research-reports"><span>DTLA Research</span><div class="menuimg" style="background-image:url(/images/menus/menu_dtlaresearch.jpg);"></div></a></li><li class="item-532"><a href="/live-here"><span>Live Here</span><div class="menuimg" style="background-image:url(/images/menus/menu_livehere.jpg);"></div></a></li><li class="item-531"><a href="/do-biz/find-space/building-finder"><span>Building Finder</span><div class="menuimg" style="background-image:url(/images/menus/menu_building_finder.jpg);"></div></a></li><li class="item-533 last"><a href="/explore/shopping/downtown-specials"><span>DTLA Deals</span><div class="menuimg" style="background-image:url(/images/menus/menu_dtladeals.jpg);"></div></a></li></ul>
# <div class="clear_it"></div></div>
# <div class="clear_it"></div>
# </div>
# </div>
# <div id="wrapper_social">
# <div id="social">
# <div class="mod_newsletter_signup">
# <p><a href="/about-us/publications/e-newsletters/newsletter-signup"><strong>Sign up for our newsletter</strong> and become a Downtown LA insider</a></p><div class="clear_it"></div></div>
# <div class="mod_menusocial"><ul class="menusocial">
# <li class="item-535"><span class="separator"><strong>Connect with </strong>Downtown LA</span>
# </li><li class="item-246"><a href="https://www.facebook.com/DowntownLA.com" target="_blank"><span>Facebook</span></a></li><li class="item-247"><a href="https://twitter.com/downtown_la" target="_blank"><span>Twitter</span></a></li><li class="item-248"><a href="https://instagram.com/downtown_la/" target="_blank"><span>Instagram</span></a></li><li class="item-254 last"><a href="https://www.youtube.com/user/ladcbid/featured" target="_blank"><span>YouTube</span></a></li></ul>
# <div class="clear_it"></div></div>
# </div>
# </div>
# <div id="wrapper_footer">
# <div id="footer">
# <div class="mod_menufootermain"><ul class="menufootermain">
# <li class="item-101"><a href="/"><span>Home</span></a></li><li class="item-223 active deeper parent"><a href="/explore"><span>Explore</span></a><ul><li class="item-260 parent"><a href="/explore/entertainment-arts-culture"><span><strong>Entertainment, </strong>Arts &amp; Culture</span></a></li><li class="item-261 active parent"><a href="/explore/dining-nightlife"><span>Dining &amp; Nightlife</span></a></li><li class="item-262 parent"><a href="/explore/getting-around"><span>Getting Around</span></a></li><li class="item-263 parent"><a href="/explore/shopping"><span>Shopping </span></a></li><li class="item-264 parent"><a href="/explore/events"><span>Events</span></a></li><li class="item-433 parent"><a href="/explore/stay"><span>Stay</span></a></li></ul></li><li class="item-224 deeper parent"><a href="/do-biz"><span>Do Biz</span></a><ul><li class="item-279 parent"><a href="/do-biz/find-space"><span>Find Space</span></a></li><li class="item-428 parent"><a href="/do-biz/business-services"><span>Business Services</span></a></li><li class="item-282 parent"><a href="/do-biz/research-information"><span><strong>Research &amp; </strong>Information</span></a></li><li class="item-281 parent"><a href="/do-biz/development"><span>Development</span></a></li><li class="item-296 parent"><a href="/do-biz/dtla-by-the-numbers"><span><strong>DTLA by </strong>the Numbers</span></a></li></ul></li><li class="item-225 deeper parent"><a href="/live-here"><span>Live Here</span></a><ul><li class="item-297 parent"><a href="/live-here/residential-building-finder"><span><strong>Residential </strong>Building Finder</span></a></li><li class="item-298"><a href="/live-here/housing-tours"><span>Housing Tours</span></a></li><li class="item-299"><a href="/live-here/neighborhoods"><span>Neighborhoods</span></a></li><li class="item-300"><a href="/live-here/education"><span>Education</span></a></li><li class="item-301 parent"><a href="/live-here/amenities-finder"><span>Amenities Finder</span></a></li><li class="item-302 parent"><a href="/live-here/community-resources"><span><strong>Community </strong>Resources</span></a></li></ul></li><li class="item-226 deeper parent"><a href="/about-us"><span>About Us</span></a><ul><li class="item-303 parent"><a href="/about-us/who-we-are"><span>Who we are</span></a></li><li class="item-305 parent"><a href="/about-us/press"><span>Press</span></a></li><li class="item-307 parent"><a href="/about-us/programs-initiatives"><span><strong>Programs &amp; </strong>Initiatives</span></a></li><li class="item-306 parent"><a href="/about-us/publications"><span>Publications</span></a></li><li class="item-308"><a href="/about-us/contact"><span>Contact</span></a></li><li class="item-432 last"><a href="/about-us/careers"><span>Careers</span></a></li></ul></li></ul>
# <div class="clear_it"></div></div>
# <div class="mod_menufootertop"><ul class="menufootertop">
# <li class="item-227"><a href="/about-us/contact"><span>Contact</span></a></li><li class="item-228"><a href="/calendar"><span>Calendar</span></a></li><li class="item-229"><a href="/maps"><span>Maps</span></a></li><li class="item-460 last"><a href="/blog"><span>Blog</span></a></li></ul>
# <div class="clear_it"></div></div>
# <div class="copyright">© 2017 Downtown Center Business Improvement District</div>
# <div class="contact_info">626 Wilshire Blvd., Ste 200, Los Angeles, CA 90017<br/><a href="mailto:marketing@downtownla.com">marketing@downtownla.com</a>  |  (213) 624.2146</div>
# <div class="footer_links"><a href="/privacy-policy">Privacy Policy</a>  |  <a href="/copyright">Copyright</a>  |   <a href="/public-records">Public Records</a>  |  <a href="/site-map">Site Map</a>  |  Site by <a href="http://www.proofinteractive.com" target="_blank">PROOF</a></div>
# </div>
# <div class="parallax"></div>
# </div>
# </div>
# </div>
# <script src="/min/g=js&amp;1480610082"></script>
# <!--[if (gte IE 6)&(lte IE 8)]>
#   <script type="text/javascript" src="/templates/js/libs/selectivizr.js"></script>
# <![endif]-->
# </body>
# </html>
# C:\Users\Zishi\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\Zishi\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
for t in table.find_all('h2', class_='name'):
    text = t.text
    for s in t.findNextSiblings():
        text += '\n' + s.text
    found_happy_hours.append(text)
print('Found %d happy hours' % len(found_happy_hours))
# Out:
# Weekday Happy Hour
# Weekday Happy Hour
# Noe Bar Happy Hour
# Monday Happy Hour
# Tuesday - Saturday Happy Hour
# Bar & Kitchen
# Big Wangs Sports Bar
# Bonaventure Brewing Company
# Monday through Friday
# Weekday Happy Hour
# Saturday Happy Hour
# Sunday Happy Hour
# Great Happy Hour
# Taco Tuesdays
# Weekday Happy Hour
# Weekend Happy Hour
# Daily Happy Hour
# Weekday Happy Hour
# Hoppy Hour
# Margarita Hour
# Weekday Happy Hour
# Daily Happy Hour
# Social Hour
# Happy Hour
# Late Night Happy Hour
# Daily Happy Hour
# Weekday Happy Hour
# Beat The Clock
# Beat The Clock - Late Night
# Daily Happy Hour
# Daily Happy Hour
# #NOBSHour
# Happy Hour
# Weekday Happy Hour
# Weekday Happy Hour
# Weekday Happy Hour
# After Work Hours
# Daily Happy Hour
# Daily Happy Hour
# Hip Hop Happy Hour
# Happy Hours
# Happy Hours
# Happy Hours
# Hora Especial
# Happy Hour
# Happy Hour
# Aperitivo Hour
# Weekday Happy Hour
# Daily Happy Hour
# Weekday Happy Hour
# Happy Hour
# Daily Happy Hour
# Found 52 happy hours
